# %%
import os
import sys

# %%
# Manually set the path relative to the py file's location that you want to import
func_lib_path = os.path.abspath(os.path.join(os.getcwd(), './..'))
# Add the path to sys.path
sys.path.append(func_lib_path)

# %%
import numpy as np
import yfinance as yf
from utils import plot_returns

# %%
# Download S&P 500 front month futures data
prices = yf.download(['ES=F', 'ZN=F'], auto_adjust=False)["Adj Close"].resample("M").last()
# Calculate logarithmic returns
log_returns = np.log(prices).diff()
# Set portfolio weights
weights = np.array([.6, .4])
# Calculate weighted returns
weighted_returns = log_returns * weights
# Calculate portfolio returns
portfolio_returns = weighted_returns.sum(axis=1)
# Out:
# [*********************100%***********************]  2 of 2 completed
# /var/folders/kc/02qzn85d4kj09bm4l_5k36hm0000gn/T/ipykernel_35949/2076215571.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   prices = yf.download(['ES=F', 'ZN=F'], auto_adjust=False)["Adj Close"].resample("M").last()

# %%
plot_returns(portfolio_returns)
