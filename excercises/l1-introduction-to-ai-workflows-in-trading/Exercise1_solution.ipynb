# %% [markdown]
# # Lesson 1: Exercise 1
#
# ## Creating Data and Backtesting a Trading Strategy
#
# ---
#
# ## Overview
#
# Welcome to this Exercise. We are now going to put our skills to the test and create a dataset and prepare our first backtests. Proper data preparation is essential to conducting succesful backtest, and we want to make sure that we build a solid foundation and develop proper techniques to ensure that we can build our datasets easily at scale and develop proper data wrangling and preparation approaches. In particular, we are going to cover the  essential steps that are necessary to succesfully build trading  models beginning from creating datasets from publicly available stock price data to conducting exploratory data analysis to finally building and testing models. We are then quickly shifts gears and illustrate a few advanced investment ideas that can be used for further analysis.
#
# Let's start by upgrading the `yfinance` module to the latest version. Run the following code block to upgrade it, then click the menu item at the top: **Kernel** > **Restart**, before running the remaining code blocks.

# %%
# !pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: requests>=2.31 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (6.31.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: pycparser in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/anaconda3/envs/und-ai-trading-strategies/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.3)

# %%
import sys
import os

# Manually set the path relative to the py file's location that you want to import
func_lib_path = os.path.abspath(os.path.join(os.getcwd(), '../'))
# Add the path to sys.path
sys.path.append(func_lib_path)
# Now you can import func_lib
import func_lib

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Calculate accuracy, precision, and recall
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
#  Create a variable named 'historical_prices' to store historical price data between the dates'2005-01-01' and '2015-01-01'. Use the function 'create_hist_prices()' from 'func_lib' to generate or retrieve the historical prices.
historical_prices = func_lib.create_hist_prices(start_date = '2005-01-01', end_date = '2015-01-01')
# Out:
# [*********************100%***********************]  501 of 501 completed
#
# 34 Failed downloads:
# ['PYPL', 'FTV', 'DASH', 'MRNA', 'VLTO', 'UBER', 'ABNB', 'KHC', 'CRWD', 'FOX', 'PLTR', 'DOW', 'LW', 'VICI', 'HWM', 'HPE', 'IR', 'KVUE', 'OTIS', 'COIN', 'SOLV', 'CARR', 'GEV', 'GDDY', 'CEG', 'FOXA', 'VST', 'CTVA', 'SW', 'INVH', 'DAY', 'DELL', 'GEHC', 'EXE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1104555600, endDate = 1420088400")')

# %%
historical_prices.head()
# Out:
# Ticker              A      AAPL  ABBV        ABT      ACGL        ACN  \
# Date
# 2005-01-03  14.358140  0.951065   NaN  13.946532  4.025470  18.524015
# 2005-01-04  13.979347  0.960832   NaN  13.806077  3.972643  18.088482
# 2005-01-05  13.973333  0.969248   NaN  13.647692  3.949399  18.018238
# 2005-01-06  13.666685  0.969999   NaN  13.955489  3.944116  17.856668
# 2005-01-07  13.654660  1.040626   NaN  14.194556  3.985321  18.692606
#
# Ticker           ADBE        ADI        ADM        ADP  ...        WTW  \
# Date                                                    ...
# 2005-01-03  30.838949  22.714375  13.590546  21.539532  ...  69.487198
# 2005-01-04  30.024111  22.096430  13.442022  21.195675  ...  69.974297
# 2005-01-05  29.859142  22.196297  13.213026  21.107260  ...  68.865738
# 2005-01-06  29.364239  22.158842  13.485336  20.964815  ...  68.580193
# 2005-01-07  29.384233  22.190052  13.516282  20.925508  ...  67.706787
#
# Ticker             WY       WYNN       XEL        XOM  XYL        YUM  \
# Date
# 2005-01-03  12.428693  35.313148  8.482779  25.327168  NaN  11.578518
# 2005-01-04  12.237625  35.237728  8.355678  25.155252  NaN  11.425195
# 2005-01-05  12.289568  35.636383  8.261530  25.023790  NaN  11.397997
# 2005-01-06  12.339649  37.080154  8.247409  25.342342  NaN  11.526589
# 2005-01-07  12.532572  35.846485  8.200332  25.175472  NaN  11.462290
#
# Ticker            ZBH       ZBRA  ZTS
# Date
# 2005-01-03  68.938141  55.509998  NaN
# 2005-01-04  68.912125  54.470001  NaN
# 2005-01-05  68.373650  52.570000  NaN
# 2005-01-06  69.163948  52.650002  NaN
# 2005-01-07  69.042336  53.099998  NaN
#
# [5 rows x 464 columns]

# %%
#  Create a variable named 'historical_prices' to store historical price data between the dates'2005-01-01' and '2015-01-01'. Use the function 'create_hist_prices()' from 'func_lib' to generate or retrieve the historical prices.
historical_prices = func_lib.create_hist_prices(start_date = '2005-01-01', end_date = '2015-01-01')
# Create a list named 'list_of_momentums' and add 1 to the list
list_of_momentums = [1]
# Compute the total returns using the historical prices and the list of momentums. Use the 'compute_returns()' function from 'func_lib'. Pass 'historical_prices' and 'list_of_momentums' as arguments to 'func_lib.compute_returns()'.
# - Store the result in a variable named 'total_returns'.
total_returns     = func_lib.compute_returns(historical_prices, list_of_momentums)
# Use the 'dropna()' method on the 'total_returns' DataFrame.
total_returns.dropna(inplace=True)
# Out:
# [*********************100%***********************]  501 of 501 completed
#
# 438 Failed downloads:
# ['PYPL', 'FTV', 'DASH', 'MRNA', 'VLTO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-01-01 -> 2015-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1104555600, endDate = 1420088400")')
# ['MSI', 'TXN']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 58 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['EMN', 'GM', 'MAA', 'STE', 'CTSH', 'META', 'LYB', 'KMB', 'PODD', 'JNJ', 'FRT', 'EA', 'MTB', 'MOS', 'UNP']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 54 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['HES', 'CBOE', 'PM', 'AMGN', 'HPE', 'WELL', 'MU', 'LH', 'IRM', 'V', 'BKNG', 'WBA', 'REGN', 'WDC', 'HCA', 'ROST', 'SNPS', 'STZ', 'VRSN', 'KLAC', 'MTD', 'DRI', 'ACGL', 'ULTA', 'CDNS', 'INTC', 'TRMB', 'LULU', 'VRTX']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 49 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['BAC', 'MKTX', 'EFX', 'DXCM', 'TT', 'FANG', 'CMS', 'ARE', 'VLO', 'CVS', 'NVR', 'HLT', 'TRV', 'ERIE', 'TSLA', 'ROP', 'DAY', 'LIN', 'CPRT']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 41 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['AON', 'COST', 'BKR', 'MSCI', 'POOL', 'LW', 'LII', 'CAH', 'COIN', 'TECH', 'RCL', 'EVRG', 'GOOGL', 'T', 'EPAM', 'CI', 'EXE', 'WTW']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 40 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['FDS', 'BXP', 'VRSK', 'PKG', 'WBD', 'AEP', 'NEE', 'AKAM', 'COO', 'WAB', 'JBL', 'NEM', 'KIM', 'ABBV', 'CPB', 'ZTS', 'VST', 'AMZN', 'KDP', 'WMB', 'ODFL', 'GPC', 'AMP', 'MPWR', 'BA', 'PNC', 'VTRS', 'ATO', 'BBY', 'AIG', 'SNA', 'EMR', 'BEN', 'FITB']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 44 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['SLB', 'K', 'HON', 'IPG', 'PAYC', 'AVY', 'TER', 'MCK', 'PCAR', 'FIS', 'JKHY', 'APO', 'BAX', 'USB', 'INCY', 'MKC', 'CNC', 'FDX', 'FI', 'UNH', 'EXC', 'LYV', 'SWKS', 'KMI', 'MNST']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 42 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['SHW', 'CMG', 'ETN', 'GD', 'CTRA', 'VICI', 'TEL', 'DHI', 'PH', 'CME', 'TGT', 'NTRS', 'ESS', 'ELV', 'WSM', 'AZO', 'SYF', 'AWK', 'HD', 'PCG', 'BX', 'D', 'EW', 'URI', 'LOW', 'HSIC', 'EQR', 'LDOS', 'DECK', 'CDW', 'TSN', 'IP', 'ENPH', 'EXPE']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 46 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['UBER', 'LEN', 'COF', 'HOLX', 'PSA', 'JPM', 'OTIS', 'GRMN', 'ALB', 'MDT', 'NWS', 'RTX', 'DELL', 'PEP']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 39 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['MET', 'CRL', 'TDY', 'TJX', 'ALLE', 'XYL', 'CINF', 'MCO']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 38 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['ABNB', 'EG', 'IDXX', 'CLX', 'PPL', 'ANET', 'LKQ', 'PHM', 'ADSK', 'BDX', 'SRE', 'WAT', 'GEN', 'TMUS', 'MS', 'CEG', 'TTWO', 'CHTR', 'RSG', 'VZ', 'STT', 'SWK', 'ADBE', 'ROL', 'DLTR', 'COP', 'MSFT', 'UDR', 'DPZ', 'NSC']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 48 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['SJM', 'DOW', 'MAR', 'DAL', 'AFL']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 36 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['MA', 'HPQ', 'LMT', 'SYK', 'A', 'ICE', 'OKE', 'IR', 'KVUE', 'MCD', 'LRCX', 'BG', 'SOLV', 'HAL', 'AXP', 'GE', 'BLK', 'DUK', 'AAPL', 'MO', 'GPN', 'FE', 'KO', 'WEC', 'GIS', 'F', 'DVN', 'GEHC', 'WRB', 'ANSS']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 47 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['UPS', 'DE', 'ABT', 'PLTR', 'BMY', 'VTR', 'HAS', 'NVDA', 'PNW', 'SW', 'PRU']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 37 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['BLDR', 'REG', 'PAYX']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 34 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['LVS', 'AOS', 'NWSA', 'BK', 'PFG', 'FICO', 'GOOG', 'IBM', 'NOC', 'WDAY', 'J', 'ALL', 'BR', 'ED', 'COR', 'BIIB', 'APH', 'NRG', 'WFC', 'ADI', 'NOW', 'XEL', 'EXPD', 'ORCL', 'CAT', 'APD', 'NI', 'AMAT', 'RMD', 'TROW', 'PSX', 'ADP', 'HST']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 43 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['KHC', 'CRWD', 'PFE', 'NKE', 'GILD', 'AMT', 'DOV', 'MMM', 'SPG', 'AVB', 'WST', 'TDG', 'GWW', 'GS', 'AMD', 'HUM', 'UAL', 'IQV', 'NDSN', 'CPT', 'FOXA', 'NCLH', 'PLD', 'AVGO', 'CHD', 'HII', 'TSCO', 'SCHW', 'CSGP', 'DGX', 'ALGN']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 45 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['EOG', 'PTC', 'O', 'WMT']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 35 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['KEY', 'AES', 'FOX', 'PANW', 'CRM', 'DG', 'CNP', 'PWR', 'IEX', 'RF', 'YUM', 'CAG', 'ADM', 'MDLZ', 'PARA', 'CCI']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 51 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['FFIV', 'SPGI', 'ON', 'GEV', 'DHR', 'CTVA']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 56 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['GLW', 'TRGP', 'SYY', 'ETR', 'DOC', 'HWM', 'OMC', 'TYL', 'HRL', 'WYNN', 'CVX', 'KMX', 'LUV', 'WY', 'MRK', 'PG', 'LHX', 'BSX', 'KKR', 'MOH']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 50 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['JNPR', 'PPG', 'TXT', 'WM', 'LNT', 'AXON', 'CBRE', 'CSX', 'STX', 'LLY']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 53 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['JCI', 'ACN', 'IVZ', 'EXR', 'NFLX', 'RVTY', 'KR', 'MHK', 'BALL', 'EQIX', 'GDDY', 'GL', 'NUE', 'MGM', 'DVA', 'APA', 'MLM']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 52 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['MAS', 'DD', 'AME', 'CARR', 'CFG']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 55 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['VMC']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 61 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['SBUX']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 70 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['CZR', 'ROK']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 66 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['STLD']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 68 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['MTCH', 'MPC', 'INVH', 'ES']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 57 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['FSLR']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 63 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['CF', 'HIG']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 64 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['IFF']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 60 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# ['MCHP']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 59 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')

# %%
# Print the first 5 lines of total returns
total_returns.head()
# Out:
#                    F_1_d_returns  1_d_returns
# Ticker Date
# AEE    2005-01-04      -0.009013    -0.007925
#        2005-01-05       0.010128    -0.009013
#        2005-01-06      -0.000409     0.010128
#        2005-01-07       0.009008    -0.000409
#        2005-01-10      -0.004464     0.009008

# %%
# Compute cumulative and calendar returns from the total returns data. 
# Use the 'compute_BM_Perf()' function from 'func_lib' to perform this calculation. 
# Pass 'total_returns' as an argument to 'func_lib.compute_BM_Perf()'.
# - The function returns two outputs: 'cum_returns' for cumulative returns and 'calendar_returns' for calendar returns.
# - Assign the outputs to the variables 'cum_returns' and 'calendar_returns' respectively.
cum_returns, calendar_returns  = func_lib.compute_BM_Perf(total_returns)
# Out:
# The CAGR is: 15.65%
# Sharpe Ratio of Strategy: 0.78

# %%
# Calculate the Relative Strength Index (RSI) for each 'Ticker' and add it to the 'total_returns' DataFrame.First, group the 'total_returns' DataFrame by the 'Ticker' column.
# For each group, select the '1_d_returns' column and apply a transformation using the 'calculate_rsi' function from 'func_lib'.
# - Assign the result to a new column named 'RSI' in the 'total_returns' DataFrame.
total_returns['RSI'] = total_returns.groupby('Ticker')[['1_d_returns']].transform(func_lib.calculate_rsi)

# %%
# Print out the first 5 rows of the total_returns dataframe
total_returns.head()
# Out:
#                    F_1_d_returns  1_d_returns  RSI
# Ticker Date
# AEE    2005-01-04      -0.009013    -0.007925  NaN
#        2005-01-05       0.010128    -0.009013  NaN
#        2005-01-06      -0.000409     0.010128  NaN
#        2005-01-07       0.009008    -0.000409  NaN
#        2005-01-10      -0.004464     0.009008  NaN

# %%
#  Define a trading strategy function based on the RSI (Relative Strength Index). Create a function named 'trading_strategy' that accepts one parameter: 'rsi'.
# Inside the function, use an if-else statement to implement the trading logic:
#     - If 'rsi' is less than 65, return 1 (indicating a decision to go long).
#     - Otherwise, return 0 (indicating no position or a different strategy).
# - This function will be used later to determine trading actions based on RSI values.

def trading_strategy(rsi):
    if rsi < 65:
        return  1 # Go long
    else:
        return 0

# %%
# Create a variable named 'model_name' and set it to the string "RSI".
model_name = "RSI"

# %%
# Compute cumulative and calendar returns for the given trading strategy.
# Use the 'compute_strat_perf()' function from 'func_lib' to perform this calculation.
# Pass 'total_returns', 'cum_returns', 'calendar_returns', 'trading_strategy', and 'model_name' as arguments.
# - The function returns updated 'cum_returns' and 'calendar_returns' based on the strategy's performance.
cum_returns, calendar_returns  = func_lib.compute_strat_perf(total_returns, cum_returns, calendar_returns, trading_strategy, model_name)
# Out:
# The CAGR is: 14.78%
# Sharpe Ratio of Strategy: 0.76

# %%
# Create the true values (y_test) indicating whether future 1-day returns (F_1_d_returns) are larger or smaller than 0.
# Use the 'np.where()' function to evaluate the 'F_1_d_returns' column in the 'total_returns' DataFrame.
# Store the result in a new column called 'y_test' in the 'total_returns' DataFrame.
total_returns['y_test'] = np.where(total_returns['F_1_d_returns']>0,1,0)
# Copy the values from the 'Position' column of 'total_returns' to a new column named 'y_pred'.
total_returns['y_pred'] = total_returns['Position']

# %%
# Convert the 'y_test' column from the 'total_returns' DataFrame to a list using the 'tolist()' method.
# Store the result in a variable named 'y_test'.
# Similarly, convert the 'y_pred' column to a list and store it in a variable named 'y_pred'.
y_test = total_returns['y_test'].tolist()
y_pred = total_returns['y_pred'].tolist()

# %%
# Calculate the accuracy, precision, and recall of the trading strategy.
# - Use the 'accuracy_score()' function to calculate the accuracy of the predictions.
#     - Pass the actual values (y_test) and the predicted values (y_pred) as arguments.
#     - Store the result in a variable named 'accuracy'.
# - Use the 'precision_score()' function to calculate the precision of the predictions.
#     - Similarly, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'precision'.
# - Use the 'recall_score()' function to calculate the recall of the predictions.
#     - Again, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'recall'.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
# Create a DataFrame named 'metrics_df' using the 'pd.DataFrame()' function.
# Define a dictionary with two keys: 'Metric' and 'Value'.
#     - The 'Metric' key should have a list of strings: ['Accuracy', 'Precision', 'Recall'].
#     - The 'Value' key should have a list of the calculated metrics: [accuracy, precision, recall].
metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [accuracy, precision, recall]
})

# %%
# Display the 'metrics_df' DataFrame to see the performance of the trading strategy.
metrics_df
# Out:
#       Metric     Value
# 0   Accuracy  0.511062
# 1  Precision  0.511639
# 2     Recall  0.937430
